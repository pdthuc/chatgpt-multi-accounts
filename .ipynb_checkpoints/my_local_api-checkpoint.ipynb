# %%
import os
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
import random
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import json
import requests
import time

# %%
labels = ["0", "1", "2", "3", "4", "5", "6", "7"]
folder_path = os.path.join(os.path.abspath(os.pardir), "Langchain")
folder_path
# Out:
# 'D:\\AIA\\ChatGPT-Conversation\\Langchain'

# %%
file_path = os.path.join(folder_path, "sales_1xx.xlsx")
df = pd.read_excel(file_path, dtype=str, keep_default_na=False)

df = df[df["label"].isin(labels)]
print(df.shape)
for i in range(8):
    print(i, list(df.label).count(str(i)))
    
X = df[["comment", "category", "new_label"]]
y = df["label"] # tmp
    
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0)
# X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=1) # 0.25 x 0.8 = 0.2
# Out:
# (832, 4)
# 0 199
# 1 116
# 2 113
# 3 163
# 4 21
# 5 35
# 6 152
# 7 33

# %%
X_train
# Out:
#                                         comment   category new_label
# 687                             Bốt c đi có k c    grocery         2
# 485                                Váy da nâu L     others         3
# 767                          Khăn này tuyệt đẹp    grocery         6
# 671                     Chân váy xinh quá em oi   clothing         6
# 150                                   tặng 3238     others         1
# ..                                          ...        ...       ...
# 763  E nhận được rồi đẹp lắm c vừa rẻ đẹp vừa ý  accessory         6
# 192                          Nha Lan vô xem nek   clothing         1
# 629       Ôi máy sấy c mới dùng đã cháy k rồi e    grocery         5
# 559                                         Đen     others         3
# 684          Nhu Doan hàng nha ba này ok lắm     others         6
#
# [748 rows x 3 columns]

# %%
dictionaries = dict()
for i in range(8):
    # get data
    tmp = X_train[X_train["new_label"]==str(i)]
    tmp = tmp.reset_index(drop=True)
    dictionaries[i] = list()
    for j in range(len(tmp)):
        comment = tmp.comment[j]
        if comment not in dictionaries[i]:
            dictionaries[i].append(comment)
with open("sample.json", "w") as outfile:
    json.dump(dictionaries, outfile)

# %%
import textdistance

# %%
dictionary_df = X_train.copy()
dictionary_df = dictionary_df.reset_index(drop=True)
dictionary_df
# Out:
#                                         comment   category new_label
# 0                               Bốt c đi có k c    grocery         2
# 1                                  Váy da nâu L     others         3
# 2                            Khăn này tuyệt đẹp    grocery         6
# 3                       Chân váy xinh quá em oi   clothing         6
# 4                                     tặng 3238     others         1
# ..                                          ...        ...       ...
# 743  E nhận được rồi đẹp lắm c vừa rẻ đẹp vừa ý  accessory         6
# 744                          Nha Lan vô xem nek   clothing         1
# 745       Ôi máy sấy c mới dùng đã cháy k rồi e    grocery         5
# 746                                         Đen     others         3
# 747          Nhu Doan hàng nha ba này ok lắm     others         6
#
# [748 rows x 3 columns]

# %%
def top_nearest_df(comment):
    N = 5
    similar = [textdistance.bz2_ncd.similarity(comment, _) for _ in dictionary_df.comment]
    res = sorted(range(len(similar)), key = lambda sub: similar[sub])[-N:]
    return dictionary_df.iloc[res, :]

# %%
label_to_text = [str(_) for _ in range(8)]
label_to_text
# Out:
# ['0', '1', '2', '3', '4', '5', '6', '7']

# %%
question_df = pd.DataFrame()
for label in labels:
    tmp = X_test[X_test["new_label"] == label]
    tmp = tmp.sample(n=min(len(tmp), 3), replace=False)
    question_df = pd.concat([question_df, tmp], axis=0)
print(question_df.shape)
question_df
# question_df = X_test.copy()
# question_df
# Out:
# (23, 3)
#                                                comment   category new_label
# 101                                        oh vậy thôi     others         0
# 247                                                 Hi   clothing         0
# 8                       Hôm nay xin Lộc 57 nha các Ông        fnb         0
# 214                     Nguyễn Thị Kim Anh ranh vô coi     others         1
# 252                                     Tặng 3 50k 357     others         1
# 239                                           tặng 824   clothing         1
# 331                                       túi gia bn e     others         2
# 306                    E Thuong mang vay size may z em     others         2
# 320                                 Bộ áo dài bn à chị   clothing         2
# 566                                           Jump den     others         3
# 501                                              Trang  accessory         3
# 460                                           Sét 130   clothing         3
# 602  Chốt hàng: Khách mới - Mã + SĐTHotline:0...   clothing         4
# 597   Đặt hàng Mã  Màu Số kí Số ĐTTrên cùng 1 tin nhắn  accessory         4
# 619           Moi nhân đơn hoi chiều đồ 25kg chật c ơi   clothing         5
# 613                đồ đẹp nhưng may hơi nhỏ quá my        fnb         5
# 631                 Shop oi gửi lôn đồ lộn cho chị rồi   clothing         5
# 712  Chai răng miệg xài ok lm c e mới mua thêm 2 ch...    grocery         6
# 735                                      Đẹp quá em ơi   clothing         6
# 717  Chị nhận dk xả rùi nhé thơm lắm nhận buổi chiề...    grocery         6
# 828                    E huyr mã 56 nha c quần e k vừa     others         7
# 812                                    Xả giùm chị nhe   clothing         7
# 817                                   Chị xã Jum dùm e     others         7

# %%
from langchain import PromptTemplate, FewShotPromptTemplate

# %%
def examples_generator(comment=""): # return a list of dict()
    examples = []
    nearest_df = top_nearest_df(comment)
    for ind in range(len(nearest_df)):
        row = nearest_df.iloc[ind]
        example = dict()
        example["comment"] = row.comment
        example["category"] = row.category
        example["label"] = row.new_label
        # example["mean"] = ?
        examples.append(example)
    return examples

# %%
examples_generator("Thanh Khang")
# Out:
# [{'comment': 'Tang 640', 'category': 'clothing', 'label': '1'},
#  {'comment': 'Tang beo', 'category': 'clothing', 'label': '1'},
#  {'comment': 'Tang 476', 'category': 'clothing', 'label': '1'},
#  {'comment': 'Thu Trang', 'category': 'fnb', 'label': '1'},
#  {'comment': 'Anh Van', 'category': 'clothing', 'label': '1'}]

# %%
def fewshot_prompt_generator(comment="", category=""):
    
    def prefix_generator():
        prefix = """Trong livestream bán hàng,
        Nếu nhắc tên người khác, muốn chia sẻ thì nhãn là 1.
        Nếu đặt câu hỏi hoặc yêu cầu thì nhãn là 2.
        Nếu chọn thông số hoặc chọn sản phẩm thì nhãn là 3.
        Nếu chốt đơn thì nhãn là 4.
        Nếu đánh giá tiêu cực, không thích thì nhãn là 5.
        Nếu đánh giá tích cực, hứng thú thì nhãn là 6.
        Nếu muốn xả hàng, muốn hủy đơn hàng thì nhãn là 7.
        Còn lại thì nhãn là 0.""".replace("\n", " ").replace("    ", "")
        return prefix
    
    
    def suffix_generator(comment="", category=""):
        suffix = 'Hãy chọn đáp án cho bình luận "' + comment + '" về sản phẩm ' + category + "."
        return suffix
    
    
    def fewshot_generator(prefix, examples, suffix):
        example_formatter_template = """ Ví dụ bình luận "{comment}" về sản phẩm {category} thì nhãn là {label}."""
        example_prompt = PromptTemplate(
            input_variables = ["comment", "category", "label"],
            template = example_formatter_template,
        ) 
        
        few_shot_prompt = FewShotPromptTemplate(
            examples = examples,
            example_prompt = example_prompt,
            prefix = prefix,
            suffix = suffix,
            input_variables = [],
            example_separator = "",
        )
        
        return few_shot_prompt
    
    prefix = prefix_generator()
    examples = examples_generator(comment=comment)
    suffix = suffix_generator(comment=comment, category=category)
    
    few_shot_prompt = fewshot_generator(prefix=prefix, examples=examples, suffix=suffix)
    prompt = few_shot_prompt.format()
    prompt = prompt + ' Trả lời theo định dạng json: {"reason": lý do chọn, "labels": 2 nhãn phù hợp nhất}'
    prompt = prompt.replace("\n", " ").replace("    ", "")
    
    return prompt

# %%
print(fewshot_prompt_generator(comment="cai dong ho dep lam c nhung kh co mau em thik", category="accessories"))
# Out:
# Trong livestream bán hàng, Nếu nhắc tên người khác, muốn chia sẻ thì nhãn là 1. Nếu đặt câu hỏi hoặc yêu cầu thì nhãn là 2. Nếu chọn thông số hoặc chọn sản phẩm thì nhãn là 3. Nếu chốt đơn thì nhãn là 4. Nếu đánh giá tiêu cực, không thích thì nhãn là 5. Nếu đánh giá tích cực, hứng thú thì nhãn là 6. Nếu muốn xả hàng, muốn hủy đơn hàng thì nhãn là 7. Còn lại thì nhãn là 0. Ví dụ bình luận "Chi ban kem trang da ma vua gioi nua" về sản phẩm others thì nhãn là 6. Ví dụ bình luận "Rat dep chuan nhung sai nho" về sản phẩm others thì nhãn là 6. Ví dụ bình luận "May bua dt chi bi chuong hu nen kg nghe dc" về sản phẩm accessory thì nhãn là 0. Ví dụ bình luận "e nhan kem roi c kem xai suong lm thom lm luon" về sản phẩm others thì nhãn là 6. Ví dụ bình luận "Chi chon cai dong ho mau nau den nhe" về sản phẩm accessory thì nhãn là 4.Hãy chọn đáp án cho bình luận "cai dong ho dep lam c nhung kh co mau em thik" về sản phẩm accessories. Trả lời theo định dạng json: {"reason": lý do chọn, "labels": 2 nhãn phù hợp nhất}

# %%
df[df["label"]=="3"]
# Out:
#           comment  category label new_label
# 168          66.0    others     3         3
# 178  tặng 539xanh  clothing     3         1
# 183          10.0    others     3         3
# 198    Vip 50k981    others     3         3
# 218      Trắng 37  clothing     3         3
# ..            ...       ...   ...       ...
# 583          28.0    others     3         3
# 584   Đầm 156 đồn  clothing     3         3
# 585       Sét sz4  clothing     3         3
# 586         220.0    others     3         3
# 587  Kẻ ca rô nhe   grocery     3         3
#
# [163 rows x 4 columns]

# %%
is_a_question_prompt_template = PromptTemplate(
    input_variables=["comment", "yes_or_no_form"],
    template=""""{comment}" có là một câu hỏi, thắc mắc hoặc câu nghi vấn.
    Chú ý câu bình luận có thể sai về ngữ pháp, dấu câu, chính tả.
    Trả về dạng json {yes_or_no_form}.""".replace("\n", " ").replace("    ", ""),
)

comment_label_prompt_template = PromptTemplate(
    input_variables=["comment", "category", "description", "labels_form"],
    template="""Mày là một người đang phát trực tiếp để bán mặc hàng {category}. Một người xem bình luận "{comment}".
    Mày hãy đánh giá câu bình luận đó và chọn 2 nhãn phù hợp.
    {description} Trả về dạng json {labels_form}""".replace("\n", " ").replace("    ", ""),
)

comment_confirm_prompt_template = PromptTemplate(
    input_variables=["comment", "category", "sub_description", "top_1", "top_2", "output_form"],
    template="""Mày là một người đang phát trực tiếp để bán mặc hàng {category}.
    Một người xem bình luận "{comment}". {top_1} hay {top_2} là nhãn phù hợp hơn cho bình luận "{comment}"". {sub_description}
    Trả về dạng json {output_form}""".replace("\n", " ").replace("    ", ""),
)

# %%
description_dict = dict()
description_dict['0'] = 'Đề cập tới một cá nhân. '
description_dict['1'] = 'Muốn chia sẻ điều gì đó. '
description_dict['2'] = 'Đưa ra yêu cầu làm gì đó. '
description_dict['3'] = 'Nêu thông số sản phẩm như kích cỡ, màu sắc, cân nặng, mã sản phẩm. '
description_dict['4'] = 'Chốt đơn hàng nhưng thiếu số điện thoại và địa chỉ. '
description_dict['5'] = 'Đề cập số điện thoại hoặc địa chỉ nhận hàng. '
description_dict['6'] = 'Đánh giá tiêu cực, tỏ thái độ không thích. '
description_dict['7'] = 'Đánh giá tích cực, hứng thú. '
description_dict['8'] = 'Muốn xả hàng, muốn hủy đơn hàng hoặc không muốn nhận hàng. '
description_dict['9'] = 'Các trường hợp khác. '
description_dict['10'] = 'Không phân tích được bình luận. '
real_pred_label = dict()
real_pred_label['0'] = '1'
real_pred_label['1'] = '1'
real_pred_label['2'] = '2'
real_pred_label['3'] = '3'
real_pred_label['4'] = '4'
real_pred_label['5'] = '4'
real_pred_label['6'] = '5'
real_pred_label['7'] = '6'
real_pred_label['8'] = '7'
real_pred_label['9'] = '0'
real_pred_label['10'] = '0'

# %%
def description_text(inds: list):
    description = "Với mô tả các nhãn như sau "
#     description = "We have descriptions for the labels as follows "
    for ind in inds:
        if str(ind) in description_dict.keys():
            description = description + str(ind) + ': ' + description_dict[str(ind)]
    return description

# %%
api = 'http://localhost:8081/labeling'
yes_or_no_form = '{"giải thích": giải thích ngắn, "đáp án": Đúng/Sai}'
labels_form = '{"giải thích": lý do chọn 2 nhãn này, "nhãn 1": nhãn thứ nhất, "nhãn 2": nhãn thứ hai}'
output_form = '{"giải thích": giải thích lý do chọn, "nhãn duy nhất": nhãn phù hợp hơn}'
description = description_text(list(range(0, len(description_dict)+1, 1)))

# %%
# import openai
# import json
# import requests
# import time
# api_keys = [
#                 "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",
#            ]
# def request_CHATGPT(requested_text, api_key=""):
#     openai.api_key = api_key
#     def request_CHATGPT(requested_text, source="GPT", api_key=""):
    
#     openai.api_key = api_key

#     sat_1 = "https://api.openai.com/v1/chat/completions"
#     hed_1 = dict()
#     hed_1["Content-type"] = "application/json"
#     hed_1['Authorization'] = 'Bearer ' + openai.api_key
    
#     data_1={
#         "model": "gpt-3.5-turbo",
#         "temperature":1,
#         "presence_penalty":0,
#         "frequency_penalty":0,
#         "top_p":1,
#         "messages": [
#             {
#                 "role": "user",
#                 "content": requested_text
#             }
#         ]
#     }
#     timeout_1=50000
#     response_json = {'Status':"It's down!"}
#     response = requests.post(url=sat_1, json=data_1, headers=hed_1, timeout=timeout_1)
#     response_json=response.json()
#     return response_json

# %%
def api_post(text):
    form_data = {'prompt': text}
    response = requests.post(api, data=form_data)
    return response.text


def output_to_json(output): # Post-processing
    try:
        i = output.index("{")
        j = len(output) - output[::-1].index("}") - 1
        res = json.loads(output[i:j+1])
    except:
        res = {}
    return res

# %%
class MyChain:
    
    def __init__(self, comment="", category=""):
        self.comment = comment
        self.category = category
        
    
    def set_value(self, comment="", category=""):
        self.comment = comment
        self.category = category
    
    
    def chain_0(self): # return bool
        prompt = is_a_question_prompt_template.format(
            comment=self.comment,
            yes_or_no_form=yes_or_no_form
        )
        response = api_post(text=prompt)
        response_json = output_to_json(response)
        output = output_to_json(response_json['output'])
        print(output)
        yes_or_no = output["đáp án"].lower()
        if "sai" in yes_or_no:
            return False
        return True
    
    
    def chain_1(self): # return 2 indexes
        prompt = comment_label_prompt_template.format(
            comment= self.comment,
            category= self.category,
            description= description,
            labels_form= labels_form
        )
        response = api_post(text=prompt)
        response_json = output_to_json(response)
        output = output_to_json(response_json['output'])
        print(output)
        top_1, top_2 = str(output["nhãn 1"]), str(output["nhãn 2"])
        return top_1, top_2
    
    
    def chain_2(self, top_1, top_2):
        sub_description = description_text([top_1, top_2])
        prompt = comment_confirm_prompt_template.format(
            comment= self.comment,
            category= self.category,
            sub_description = sub_description,
            top_1= top_1,
            top_2= top_2,
            output_form=output_form
        )
        response = api_post(text=prompt)
        response_json = output_to_json(response)
        output = output_to_json(response_json['output'])
        if output == {}:
            response_json_output = response_json['output']
            label = '10'
            for tmp in description_dict.keys():
                if tmp in response_json_output:
                    label = tmp
                    break
            output = {"giải thích": response_json_output, "nhãn duy nhất": label}
            
        print(output)
        return output
    
    
    def execute(self):
        is_question = self.chain_0()
        if is_question:
            return {"giải thích": "Chắc chắn là câu hỏi", "nhãn duy nhất": 2}
        
        try:
            top_1, top_2 = self.chain_1()
        except Exception as e:
            err = "Lỗi ---> " + str(e)
            return {"giải thích": err, "nhãn 1": "9", "nhãn 2": "10"}

        try:
            output = self.chain_2(top_1, top_2)
        except Exception as e:
            err = "Lỗi ---> " + str(e)
            output = {"giải thích": err, "nhãn duy nhất": top_1}
        return output

# %%
cur_time = time.time()
test_comment = "Thuong mac vay size may z em"
test_category = "clothing"
test_chain = MyChain(comment=test_comment, category=test_category)
x = test_chain.execute()
print(time.time()-cur_time)
# Out:
# {'giải thích': 'Câu này không phải là một câu hỏi, thắc mắc hoặc câu nghi vấn. Nó chỉ là một câu bình luận không rõ ý nghĩa.', 'đáp án': 'Sai'}
# {'giải thích': 'Câu bình luận này đề cập đến việc mặc vay size, cho thấy ý kiến về sản phẩm.', 'nhãn 1': 3, 'nhãn 2': 7}
# {'giải thích': "Bình luận 'Thuong mac vay size may z em' yêu cầu cung cấp thông số sản phẩm như kích cỡ, màu sắc, cân nặng và mã sản phẩm. Nhãn 3 phù hợp hơn vì nó tương ứng với mô tả này.", 'nhãn duy nhất': 3}
# 35.36249613761902

# %%
y_pred, y_true, y_mean = [], [], []
y_comment, y_category = [], []

for i in range(len(question_df)):
# for i in range(10):
    print("time-------->", i)
    row = question_df.iloc[i]
    y_category.append(row["category"])
    y_comment.append(row["comment"])
    y_true.append(label_to_text[int(row["new_label"])])
    
    print(row["category"])
    print(row["comment"])
    
    try:
        myChain = MyChain(comment=row["comment"], category=row["category"])
        output = myChain.execute()

        pred = real_pred_label[str(output["nhãn duy nhất"])]
        mean = output["giải thích"]
    except Exception as e:
        pred = '0'
        mean = e

    y_pred.append(pred)
    y_mean.append(mean)
    
print("Done.")
# Out:
# time--------> 0
# others
# oh vậy thôi
# {'giải thích': "'oh vậy thôi' không phải là một câu hỏi, thắc mắc hoặc câu nghi vấn. Thực tế, câu này thường được sử dụng như một lời bình luận hoặc phản ứng để diễn đạt sự chấp nhận, sự đồng ý hoặc sự chán nản. Nó không chứa dấu chấm hỏi hoặc cấu trúc câu hỏi thông thường. Vì vậy, câu này không phải là một câu hỏi, thắc mắc hoặc câu nghi vấn.", 'đáp án': 'Sai'}
# {'giải thích': "Bình luận 'oh vậy thôi' không đề cập tới một cá nhân hoặc chia sẻ điều gì đó cụ thể. Tuy nhiên, nó có thể được hiểu như một đánh giá tiêu cực hoặc tỏ thái độ không thích.", 'nhãn 1': 6, 'nhãn 2': 9}
# {'giải thích': "Bình luận 'oh vậy thôi' không thể chắc chắn chỉ là đánh giá tiêu cực hoặc tỏ thái độ không thích. Nó có thể có nhiều ý nghĩa khác nhau tùy thuộc vào ngữ cảnh và cách diễn đạt của người viết. Do đó, nhãn phù hợp hơn cho bình luận này là 9: Các trường hợp khác.", 'nhãn duy nhất': 9}
# time--------> 1
# clothing
# Hi
# {'giải thích': "'Hi' không phải là một câu hỏi, thắc mắc hoặc câu nghi vấn. Nó là một lời chào thông thường trong tiếng Anh.", 'đáp án': 'Sai'}
# {'giải thích': "Bình luận 'Hi' không rõ ràng để xác định một cách chính xác 2 nhãn phù hợp, tuy nhiên, dựa trên những thông tin có sẵn, ta có thể chọn các nhãn sau:", 'nhãn 1': 0, 'nhãn 2': 1}
# {'giải thích': 'Dựa trên mô tả của bạn, nhãn phù hợp hơn cho bình luận "Hi" là nhãn số 1: "Muốn chia sẻ điều gì đó".\nGiải thích: Bình luận "Hi" trong trường hợp này không đề cập đến một cá nhân cụ thể, mà có ý nghĩa là người xem muốn chia sẻ điều gì đó hoặc bày tỏ sự quan tâm.', 'nhãn duy nhất': '1'}
# time--------> 2
# fnb
# Hôm nay xin Lộc 57 nha các Ông
# {'giải thích': 'Đây không phải là một câu hỏi, thắc mắc hoặc câu nghi vấn.', 'đáp án': 'Sai'}
# {'giải thích': "Câu bình luận 'Hôm nay xin Lộc 57 nha các Ông' không phù hợp với bất kỳ nhãn nào trong danh sách.", 'nhãn 1': 10, 'nhãn 2': 9}
# {'giải thích': 'Bình luận không phân tích được ý nghĩa hoặc nội dung cụ thể.', 'nhãn duy nhất': 9}
# time--------> 3
# others
# Nguyễn Thị Kim Anh ranh vô coi
# {'giải thích': "Câu 'Nguyễn Thị Kim Anh ranh vô coi' không phải là một câu hỏi, thắc mắc hoặc câu nghi vấn, mà là một câu bình luận hoặc miêu tả. Tuy nhiên, câu này có thể sai về ngữ pháp và chính tả.", 'đáp án': 'Sai'}
# {'giải thích': "Câu bình luận 'Nguyễn Thị Kim Anh ranh vô coi' không rõ ràng để được phân loại chính xác vào một hoặc hai nhãn cụ thể. Câu này không đề cập tới một cá nhân cụ thể hoặc sản phẩm, không muốn chia sẻ điều gì đó, không đưa ra yêu cầu cụ thể, không có thông số sản phẩm, không chốt đơn hàng hoặc đưa ra thông tin số điện thoại hoặc địa chỉ nhận hàng. Ngoài ra, câu này cũng không thể xem là đánh giá tích cực hoặc tiêu cực. Do đó, câu bình luận này không phù hợp với bất kỳ nhãn nào trong danh sách đã cho.", 'nhãn 1': 10, 'nhãn 2': None}
# {'giải thích': 'Nhãn phù hợp hơn cho bình luận "Nguyễn Thị Kim Anh ranh vô coi" là 10.\nGiải thích lý do chọn nhãn 10:\nNhãn 10 đại diện cho việc "Không phân tích được bình luận."\nBình luận "Nguyễn Thị Kim Anh ranh vô coi" không cung cấp đủ thông tin hoặc mang tính chất mập mờ, không rõ ràng để có thể phân tích hoặc đưa ra một nhận xét cụ thể.\nVới sự thiếu thông tin và sự mơ hồ của bình luận này, không thể xác định được ý kiến hoặc đánh giá cụ thể từ người viết bình luận.\nVì vậy, nhãn phù hợp hơn là 10, với giải thích là không phân tích được bình luận.', 'nhãn duy nhất': '0'}
# time--------> 4
# others
# Tặng 3 50k 357
# {'giải thích': 'Đây không phải là một câu hỏi, thắc mắc hoặc câu nghi vấn.', 'đáp án': 'Sai'}
# {'giải thích': "Câu bình luận 'Tặng 3 50k 357' có thể được đánh giá như sau:", 'nhãn 2': 1, 'nhãn 1': 9}
# {'giải thích': 'Bình luận có vẻ như một thông báo hoặc tin tức về việc tặng quà.', 'nhãn duy nhất': '9'}
# time--------> 5
# clothing
# tặng 824
# {'giải thích': 'Đây không phải là một câu hỏi, thắc mắc hay câu nghi vấn mà là một cụm từ không hoàn chỉnh. Thiếu thông tin hoặc ngữ cảnh để hiểu rõ ý nghĩa của câu.', 'đáp án': 'Sai'}
# {'giải thích': "Bình luận 'tặng 824' không rõ ràng và không cho thấy ý định của người viết. Tuy nhiên, có thể chúng ta có thể chọn 2 nhãn phù hợp dựa trên những phỏng đoán và giả định.", 'nhãn 1': 9, 'nhãn 2': 1}
# {'giải thích': 'Bởi vì câu bình luận không rõ ràng đề cập đến các trường hợp khác, mà thay vào đó có vẻ như một lời chia sẻ hoặc thông điệp được người viết bày tỏ.', 'nhãn duy nhất': 1}
# time--------> 6
# others
# túi gia bn e
# {'giải thích': 'Đây không phải là một câu hỏi, thắc mắc hoặc câu nghi vấn hợp lý trong tiếng Việt.', 'đáp án': 'Sai'}
# {'giải thích': "Câu bình luận 'túi gia bn e' có thể được đánh giá là cùng lúc chứa hai nhãn phù hợp: Nhãn 0 - Đề cập tới một cá nhân và Nhãn 6 - Đánh giá tiêu cực, tỏ thái độ không thích.", 'nhãn 1': 0, 'nhãn 2': 6}
# {'giải thích': "Từ 'gia' có ý chỉ giả, không thật, trong khi 'bn e' có thể mang ý chỉ khinh miệt hoặc không tôn trọng.", 'nhãn duy nhất': 6}
# time--------> 7
# others
# E Thuong mang vay size may z em
# {'giải thích': 'Đây là một câu hỏi hoặc thắc mắc.', 'đáp án': 'Đúng'}
# time--------> 8
# clothing
# Bộ áo dài bn à chị
# time--------> 9
# others
# Jump den
# {'giải thích': "Câu 'Jump den' không phải là một câu hỏi, thắc mắc hoặc câu nghi vấn hợp lệ trong tiếng Việt.", 'đáp án': 'Sai'}
# {'giải thích': "Câu bình luận 'Jump den' không rõ ràng và không cung cấp đủ thông tin để xác định nhãn một cách chính xác. Tuy nhiên, dựa trên các tùy chọn nhãn đã được cung cấp, hai nhãn có thể được chọn để mô tả câu bình luận là:", 'nhãn 1': 9, 'nhãn 2': 10}
# {'giải thích': "Nhãn phù hợp hơn cho bình luận 'Jump den' là 10: Không phân tích được bình luận.", 'nhãn duy nhất': 10}
# time--------> 10
# accessory
# Trang
# {'giải thích': "Câu 'Trang' không phải là một câu hỏi, thắc mắc hoặc câu nghi vấn đầy đủ. Nó chỉ là một từ đơn không chứa thông tin đủ để hình thành một câu hoàn chỉnh.", 'đáp án': 'Sai'}
# {}
# time--------> 11
# clothing
# Sét 130
# {'giải thích': 'Không phải là một câu hỏi, thắc mắc hoặc câu nghi vấn.', 'đáp án': 'Sai'}
# {'giải thích': "Câu bình luận 'Sét 130' không cung cấp đủ thông tin để xác định mục đích hoặc ý định của người viết. Tuy nhiên, có thể đánh giá câu bình luận này theo hai nhãn phù hợp:", 'nhãn 1': 3, 'nhãn 2': 9}
# time--------> 12
# clothing
# Chốt hàng: Khách mới - Mã + SĐTHotline:0967.673.671… Xem thêm2
# {'giải thích': 'Câu này không phải là một câu hỏi, thắc mắc hoặc câu nghi vấn. Nó là một thông báo hoặc quảng cáo.', 'đáp án': 'Sai'}
# {'giải thích': 'Bình luận đề cập đến việc chốt hàng và yêu cầu mã sản phẩm và số điện thoại hotline. Do đó, tôi chọn nhãn 2: Đưa ra yêu cầu làm gì đó và nhãn 3: Nêu thông số sản phẩm như kích cỡ, màu sắc, cân nặng, mã sản phẩm.', 'nhãn 1': 2, 'nhãn 2': 3}
# {'giải thích': 'Nhãn số 3 (Nêu thông số sản phẩm) phù hợp hơn với bình luận này, vì nó đề cập đến việc cung cấp thông tin chi tiết về kích cỡ, màu sắc, cân nặng và mã sản phẩm.', 'nhãn duy nhất': 3}
# time--------> 13
# accessory
# Đặt hàng Mã  Màu Số kí Số ĐTTrên cùng 1 tin nhắn
# {'giải thích': 'Đúng', 'đáp án': 'Đúng'}
# time--------> 14
# clothing
# Moi nhân đơn hoi chiều đồ 25kg chật c ơi
# {'giải thích': 'Câu này không phải là một câu hỏi, thắc mắc hoặc câu nghi vấn. Nó là một câu chủ động diễn tả một tình huống.', 'đáp án': 'Sai'}
# {'giải thích': 'Bình luận này đưa ra yêu cầu liên quan đến đặt hàng của một cá nhân và cung cấp thông tin về cân nặng của đồ hàng.', 'nhãn 1': 2, 'nhãn 2': 3}
# {'giải thích': 'Câu bình luận đề cập đến thông số sản phẩm như cân nặng.', 'nhãn duy nhất': '3'}
# time--------> 15
# fnb
# đồ đẹp nhưng may hơi nhỏ quá my
# {'giải thích': 'Đây không phải là một câu hỏi, thắc mắc hoặc câu nghi vấn. Đây là một câu bình luận.', 'đáp án': 'Sai'}
# {'giải thích': 'Câu bình luận này chứa yếu tố muốn chia sẻ điều gì đó và đưa ra yêu cầu làm gì đó.', 'nhãn 1': 1, 'nhãn 2': 2}
# {'giải thích': 'Bình luận trông giống như một phản hồi, ý kiến hoặc chia sẻ từ người xem về sản phẩm.', 'nhãn duy nhất': '1'}
# time--------> 16
# clothing
# Shop oi gửi lôn đồ lộn cho chị rồi
# {'giải thích': 'Câu này không phải là một câu hỏi, thắc mắc hay câu nghi vấn mà nó có vẻ như là một lời nhắn.', 'đáp án': 'Sai'}
# {'giải thích': 'Câu bình luận đề cập đến một cá nhân (chị) và đưa ra yêu cầu làm gì đó (gửi lô đồ lộn).', 'nhãn 1': 0, 'nhãn 2': 2}
# {'giải thích': 'Nhãn phù hợp hơn là 2: Đưa ra yêu cầu làm gì đó.', 'nhãn duy nhất': 2}
# time--------> 17
# grocery
# Chai răng miệg xài ok lm c e mới mua thêm 2 chai nữa chờ nhận hàg nak c
# {'giải thích': 'Đây không phải là một câu hỏi, thắc mắc hoặc câu nghi vấn mà là một bình luận hoặc phát biểu.', 'đáp án': 'Sai'}
# {'giải thích': 'Câu bình luận này đề cập đến sản phẩm và thể hiện một sự hài lòng với nó.', 'nhãn 1': 7, 'nhãn 2': 3}
# {'giải thích': "Bình luận 'Chai răng miệg xài ok lm c e mới mua thêm 2 chai nữa chờ nhận hàg nak c' không nêu thông số sản phẩm như kích cỡ, màu sắc, cân nặng, mã sản phẩm. Thay vào đó, nó đề cập đến trải nghiệm sử dụng và việc mua thêm sản phẩm. Điều này cho thấy bình luận tập trung vào đánh giá tích cực và hứng thú với sản phẩm.", 'nhãn duy nhất': '7'}
# time--------> 18
# clothing
# Đẹp quá em ơi
# {'giải thích': "Câu 'Đẹp quá em ơi' không phải là một câu hỏi, thắc mắc hoặc câu nghi vấn. Nó là một câu bình luận hoặc lời khen với nội dung 'đẹp quá'.", 'đáp án': 'Sai'}
# {'giải thích': "Bình luận 'Đẹp quá em ơi' có thể được đánh giá là chứa nhãn 7: Đánh giá tích cực, hứng thú và nhãn 1: Muốn chia sẻ điều gì đó.", 'nhãn 1': 1, 'nhãn 2': 7}
# {'giải thích': 'Giải thích lý do chọn nhãn "7: Đánh giá tích cực, hứng thú":\nBình luận "Đẹp quá em ơi" thể hiện sự ấn tượng tích cực và hứng thú của người xem về mặt hàng clothing mà bạn đang phát trực tiếp. Nhãn "7" phù hợp với tình huống này vì nó thể hiện sự đánh giá tích cực và sự hứng thú với sản phẩm. Người xem có ý muốn thể hiện sự hài lòng và đánh giá cao về sản phẩm, không chỉ đơn thuần muốn chia sẻ mà còn muốn thể hiện sự hứng thú và đánh giá tích cực về mặt hàng clothing.\nNhãn duy nhất phù hợp hơn là "7".', 'nhãn duy nhất': '7'}
# time--------> 19
# grocery
# Chị nhận dk xả rùi nhé thơm lắm nhận buổi chiều tối giặt đồ sài lun ok lắm ý1
# {'giải thích': 'Câu này không phải là một câu hỏi, thắc mắc hoặc câu nghi vấn. Nó có thể được coi là một lời nhận xét hoặc lời mời.', 'đáp án': 'Sai'}
# {'giải thích': 'Câu bình luận được đánh giá là có hai nhãn phù hợp: 1 và 5.', 'nhãn 1': 1, 'nhãn 2': 5}
# {'giải thích': 'Bình luận này có vẻ như người xem muốn chia sẻ điều gì đó về sản phẩm xả và việc giặt đồ vào buổi chiều tối.', 'nhãn duy nhất': 1}
# time--------> 20
# others
# E huyr mã 56 nha c quần e k vừa
# {'giải thích': 'Câu này không phải là một câu hỏi, thắc mắc hay câu nghi vấn. Nó không có cấu trúc hoàn chỉnh và không rõ ý nghĩa.', 'đáp án': 'Sai'}
# {'giải thích': 'Câu bình luận này đưa ra yêu cầu làm gì đó và đề cập đến một cá nhân.', 'nhãn 1': 2, 'nhãn 2': 0}
# {'giải thích': 'Nhãn phù hợp hơn cho bình luận "E huyr mã 56 nha c quần e k vừa" là nhãn 0: Đề cập tới một cá nhân.\nGiải thích:\nNhãn 2 ("Đưa ra yêu cầu làm gì đó") không phù hợp vì trong bình luận không có yêu cầu cụ thể hoặc đề cập đến hành động cần thực hiện.\nNhãn 0 ("Đề cập tới một cá nhân") phù hợp hơn vì bình luận có chứa các từ ngữ như "E" (đại từ chỉ người) và "quần e" (quần của tôi). Điều này cho thấy bình luận đề cập đến một cá nhân nào đó (có thể là người viết bình luận).', 'nhãn duy nhất': '0'}
# time--------> 21
# clothing
# Xả giùm chị nhe
# {'giải thích': 'Đây không phải là một câu hỏi, thắc mắc hoặc câu nghi vấn. Thay vào đó, đó là một yêu cầu hoặc lời nhờ vả.', 'đáp án': 'Sai'}
# {'giải thích': 'Câu bình luận đề cập đến việc xả giúp chị, điều này có thể liên quan đến việc giảm giá, khuyến mãi hoặc giúp chị bán hàng. Do đó, nhãn phù hợp nhất là nhãn 2: Đưa ra yêu cầu làm gì đó. Tuy nhiên, câu bình luận cũng có thể ám chỉ đến một cá nhân (chị), nên nhãn phù hợp thứ hai là nhãn 0: Đề cập tới một cá nhân.', 'nhãn 1': 2, 'nhãn 2': 0}
# {'giải thích': 'Dựa trên mô tả của bạn, nhãn phù hợp hơn cho bình luận "Xả giùm chị nhe" là 0: Đề cập tới một cá nhân.\nGiải thích lý do chọn:\nNhãn 0 ("Đề cập tới một cá nhân") phù hợp vì bình luận "Xả giùm chị nhe" rõ ràng đề cập đến một người chị cần được giảm giá hoặc nhượng bán một số sản phẩm.\nNhãn 2 ("Đưa ra yêu cầu làm gì đó") không phù hợp vì bình luận không đưa ra một yêu cầu cụ thể, mà chỉ nhắc đến việc "xả giúp chị".\nDo đó, nhãn duy nhất phù hợp hơn cho bình luận "Xả giùm chị nhe" là 0.', 'nhãn duy nhất': '0'}
# time--------> 22
# others
# Chị xã Jum dùm e
# {'giải thích': "Câu 'Chị xã Jum dùm e' không phải là một câu hỏi, thắc mắc hoặc câu nghi vấn.", 'đáp án': 'Sai'}
# {'giải thích': "Câu bình luận 'Chị xã Jum dùm e' có thể được đánh giá là chứa hai nhãn: 0 và 2.", 'nhãn 1': 0, 'nhãn 2': 2}
# {'giải thích': 'Với mô tả của bạn, nhãn phù hợp hơn cho bình luận "Chị xã Jum dùm e" là nhãn 2: Đưa ra yêu cầu làm gì đó.\nGiải thích lý do chọn:\nNhãn 0: Đề cập tới một cá nhân không phù hợp với ngữ cảnh bình luận "Chị xã Jum dùm e" trong trường hợp này. "Chị xã Jum" không được đề cập là một cá nhân cụ thể, mà có thể là một cách gọi thông thường hoặc biệt danh trong một cộng đồng nhất định.\nNhãn 2: Đưa ra yêu cầu làm gì đó phù hợp hơn với ngữ cảnh bình luận này. Bình luận này yêu cầu "Chị xã Jum" giúp đỡ hoặc làm một việc gì đó cho người viết bình luận ("e" có thể được hiểu là "em" - một từ chỉ người thứ nhất số ít).\nVì vậy, nhãn phù hợp hơn cho bình luận "Chị xã Jum dùm e" là 2: Đưa ra yêu cầu làm gì đó.', 'nhãn duy nhất': '0'}
# Done.

# %%
chatgpt_df = pd.DataFrame()
chatgpt_df["category"] = y_category
chatgpt_df["comment"] = y_comment
chatgpt_df["y_true"] = y_true
chatgpt_df["y_pred"] = y_pred
chatgpt_df["y_mean"] = y_mean

chatgpt_df
# Out:
#      category                                            comment y_true  \
# 0      others                                        oh vậy thôi      0
# 1    clothing                                                 Hi      0
# 2         fnb                     Hôm nay xin Lộc 57 nha các Ông      0
# 3      others                     Nguyễn Thị Kim Anh ranh vô coi      1
# 4      others                                     Tặng 3 50k 357      1
# 5    clothing                                           tặng 824      1
# 6      others                                       túi gia bn e      2
# 7      others                    E Thuong mang vay size may z em      2
# 8    clothing                                 Bộ áo dài bn à chị      2
# 9      others                                           Jump den      3
# 10  accessory                                              Trang      3
# 11   clothing                                           Sét 130      3
# 12   clothing  Chốt hàng: Khách mới - Mã + SĐTHotline:0...      4
# 13  accessory   Đặt hàng Mã  Màu Số kí Số ĐTTrên cùng 1 tin nhắn      4
# 14   clothing           Moi nhân đơn hoi chiều đồ 25kg chật c ơi      5
# 15        fnb                đồ đẹp nhưng may hơi nhỏ quá my      5
# 16   clothing                 Shop oi gửi lôn đồ lộn cho chị rồi      5
# 17    grocery  Chai răng miệg xài ok lm c e mới mua thêm 2 ch...      6
# 18   clothing                                      Đẹp quá em ơi      6
# 19    grocery  Chị nhận dk xả rùi nhé thơm lắm nhận buổi chiề...      6
# 20     others                    E huyr mã 56 nha c quần e k vừa      7
# 21   clothing                                    Xả giùm chị nhe      7
# 22     others                                   Chị xã Jum dùm e      7
#
#    y_pred                                             y_mean
# 0       0  Bình luận 'oh vậy thôi' không thể chắc chắn ch...
# 1       1  Dựa trên mô tả của bạn, nhãn phù hợp hơn cho b...
# 2       0  Bình luận không phân tích được ý nghĩa hoặc nộ...
# 3       1  Nhãn phù hợp hơn cho bình luận "Nguyễn Thị Kim...
# 4       0  Bình luận có vẻ như một thông báo hoặc tin tức...
# 5       1  Bởi vì câu bình luận không rõ ràng đề cập đến ...
# 6       5  Từ 'gia' có ý chỉ giả, không thật, trong khi '...
# 7       2                               Chắc chắn là câu hỏi
# 8       0                                           'output'
# 9       0  Nhãn phù hợp hơn cho bình luận 'Jump den' là 1...
# 10      0                                    'nhãn duy nhất'
# 11      3                                  Lỗi ---> 'output'
# 12      3  Nhãn số 3 (Nêu thông số sản phẩm) phù hợp hơn ...
# 13      2                               Chắc chắn là câu hỏi
# 14      3  Câu bình luận đề cập đến thông số sản phẩm như...
# 15      1  Bình luận trông giống như một phản hồi, ý kiến...
# 16      2   Nhãn phù hợp hơn là 2: Đưa ra yêu cầu làm gì đó.
# 17      6  Bình luận 'Chai răng miệg xài ok lm c e mới mu...
# 18      6  Giải thích lý do chọn nhãn "7: Đánh giá tích c...
# 19      1  Bình luận này có vẻ như người xem muốn chia sẻ...
# 20      1  Nhãn phù hợp hơn cho bình luận "E huyr mã 56 n...
# 21      1  Dựa trên mô tả của bạn, nhãn phù hợp hơn cho b...
# 22      1  Với mô tả của bạn, nhãn phù hợp hơn cho bình l...

# %%
chatgpt_df.to_excel("res_84_00.xlsx", index=False)

# %%
# chatgpt_df = chatgpt_df.iloc[list(range(0,46,1))]
# chatgpt_df

# %%
chatgpt_df.shape
# Out:
# (23, 5)

# %%
y_pred_rp = [_ for _ in chatgpt_df.y_pred]
y_true_rp = [_ for _ in chatgpt_df.y_true]

# %%
print(set(y_pred_rp))
print(set(y_true_rp))
# Out:
# {'0'}
# {'5', '6', '2', '3', '7', '1', '4', '0'}

# %%
clf_report = classification_report(y_true_rp,
                                   y_pred_rp,
                                   labels=label_to_text,
                                   target_names=label_to_text,
                                   output_dict=True)

clf_report_df = pd.DataFrame(clf_report).iloc[:, :].T
clf_report_df["support"] = clf_report_df["support"].astype(int)

mask = np.zeros((len(label_to_text)+3, 4))
mask[:,3] = True
sns.heatmap(clf_report_df, mask=mask, cmap="Greens")
sns.heatmap(clf_report_df, alpha=0, cbar=False, annot=True, annot_kws={"size": 14, "color":"indianred"})

plt.show()



cm = []
for a0 in confusion_matrix(y_true_rp, y_pred_rp):
    s = sum(a0)
    cm.append([np.round(_/s, 2) for _ in a0])

plt.figure(figsize=(8, 6))
ax = sns.heatmap(cm, annot=True, cmap='Blues', fmt='g', annot_kws={"size": 16})
ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(labels)
ax.yaxis.set_ticklabels(labels)

# Display the visualization of the Confusion Matrix.
plt.show()
# Out:
# C:\Users\test\miniconda3\envs\chatmode-env\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\test\miniconda3\envs\chatmode-env\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\test\miniconda3\envs\chatmode-env\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
all_candidates = [4, 5, 4, 5, 6, 7, 8, 7, 6, 5, 4, 4, 3, 5, 5, 5, 5, 5, 3, 2, 1, 9]
selected_label = sorted(all_candidates, key = lambda label: all_candidates.count(label))[-1]
selected_label
# Out:
# 5
